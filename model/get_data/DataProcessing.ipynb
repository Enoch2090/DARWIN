# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
import warnings
import numpy as np
# import altair as alt
import copy

warnings.filterwarnings('ignore')
# _ = alt.data_transformers.disable_max_rows()

# %%
df = pd.read_json('info.json')

# %%
df.head()
# Out:
#                                      name  price  \
# 0               2018 Ford Escape Titanium  25411
# 1              2013 Jaguar XJ L Portfolio  28977
# 2              2020 Volvo S60 T5 Momentum  32900
# 3  2021 Toyota Highlander Hybrid Platinum  49846
# 4               2020 Lexus NX 300 F Sport  38689
#
#                                               basics  \
# 0  {'exterior_color': 'Blue Metallic', 'interior_...
# 1  {'exterior_color': 'Ultimate Black', 'interior...
# 2  {'exterior_color': 'Osmium Gray Metallic', 'in...
# 3  {'exterior_color': 'Black', 'interior_color': ...
# 4  {'exterior_color': 'Atomic Silver', 'interior_...
#
#                                             features
# 0  {'heated_seats': True, 'heated_steering_wheel'...
# 1  {'heated_seats': False, 'heated_steering_wheel...
# 2  {'heated_seats': False, 'heated_steering_wheel...
# 3  {'heated_seats': True, 'heated_steering_wheel'...
# 4  {'heated_seats': False, 'heated_steering_wheel...

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Expand dictionary data, extract year

# %%
df_expand = pd.concat([df.drop(['basics', 'features'], axis=1), 
                       df['basics'].apply(pd.Series), df['features'].apply(pd.Series)], axis=1)
df_expand['year'] = df_expand['name'].apply(lambda x: int(re.search(r'^\d+', x).group(0)))

# %%
df_expand.columns
# Out:
# Index(['name', 'price', 'exterior_color', 'interior_color', 'drive_train',
#        'mpg', 'fuel_type', 'transmission', 'engine', 'mileage', 'heated_seats',
#        'heated_steering_wheel', 'nav_sys', 'remote_start', 'carplay',
#        'bluetooth', 'brake_assist', 'blind_spot_monitor', 'year'],
#       dtype='object')

# %% [markdown]
# ### Set up filter for safety, comfort, multimedia configs

# %%
def filter(df, feature_list):
    df_filtered = copy.deepcopy(df)
    for feature in feature_list:
        df_filtered = df_filtered[df_filtered[feature] == True]
    return df_filtered

# %%
safety_list = ['brake_assist', 'blind_spot_monitor']
comfort_list = ['heated_seats', 'heated_steering_wheel', 'remote_start']
multimedia_list = ['nav_sys', 'carplay', 'bluetooth']

# %%
filter(filter(filter(df_expand, safety_list), comfort_list), multimedia_list)
# Out:
#                                   name  price             exterior_color  \
# 0            2018 Ford Escape Titanium  25411              Blue Metallic
# 18           2018 Ford Escape Titanium  25411              Blue Metallic
# 20                  2020 Ford Edge SEL  30997          Magnetic Metallic
# 31               2020 Nissan Murano SL  40750  Brilliant Silver Metallic
# 142        2018 Volvo XC60 T6 Momentum  40798        Onyx Black Metallic
# ...                                ...    ...                        ...
# 9018          2018 Ford Explorer Sport  44491          Magnetic Metallic
# 9169        2018 Chevrolet Suburban LT  50277                      WHITE
# 9181  2018 Jeep Grand Cherokee Limited  32205     Bright White Clearcoat
# 9193       2018 Ford Explorer Platinum  40590                   Platinum
# 9196        2020 Volvo V60 T5 Momentum  37962       Osmium Gray Metallic
#
#                  interior_color        drive_train    mpg      fuel_type  \
# 0                Charcoal Black  Front-wheel Drive  21–28       Gasoline
# 18               Charcoal Black  Front-wheel Drive  21–28       Gasoline
# 20                        Ebony    All-wheel Drive  21–28       Gasoline
# 31                     Graphite    All-wheel Drive  20–28       Gasoline
# 142                       Blond    All-wheel Drive  21–27       Gasoline
# ...                         ...                ...    ...            ...
# 9018                Ebony Black   Four-wheel Drive  16–22       Gasoline
# 9169                  Jet Black   Four-wheel Drive  15–22  E85 Flex Fuel
# 9181  Light Frost Beige / Black   Rear-wheel Drive  19–26       Gasoline
# 9193        Medium Soft Ceramic   Four-wheel Drive  16–22       Gasoline
# 9196                   Charcoal  Front-wheel Drive  23–34       Gasoline
#
#                              transmission                      engine  \
# 0                       6-Speed Automatic  2.0L I4 16V GDI DOHC Turbo
# 18                      6-Speed Automatic  2.0L I4 16V GDI DOHC Turbo
# 20                      8-Speed Automatic  2.0L I4 16V GDI DOHC Turbo
# 31                          Automatic CVT       3.5L V6 24V MPFI DOHC
# 142                     8-Speed Automatic        2.0L I4 16V GDI DOHC
# ...                                   ...                         ...
# 9018  6-Speed Automatic with Select-Shift          V6 Cylinder Engine
# 9169                            AUTOMATIC           8 Cylinder Engine
# 9181                    8-Speed Automatic       3.6L V6 24V MPFI DOHC
# 9193  6-Speed Automatic with Select-Shift          V6 Cylinder Engine
# 9196                    8-Speed Automatic  2.0L I4 16V GDI DOHC Turbo
#
#       mileage  heated_seats  heated_steering_wheel  nav_sys  remote_start  \
# 0       47114          True                   True     True          True
# 18      47114          True                   True     True          True
# 20      27075          True                   True     True          True
# 31      13566          True                   True     True          True
# 142     19730          True                   True     True          True
# ...       ...           ...                    ...      ...           ...
# 9018    17865          True                   True     True          True
# 9169    55245          True                   True     True          True
# 9181    24855          True                   True     True          True
# 9193    26623          True                   True     True          True
# 9196    22500          True                   True     True          True
#
#       carplay  bluetooth  brake_assist  blind_spot_monitor  year
# 0        True       True          True                True  2018
# 18       True       True          True                True  2018
# 20       True       True          True                True  2020
# 31       True       True          True                True  2020
# 142      True       True          True                True  2018
# ...       ...        ...           ...                 ...   ...
# 9018     True       True          True                True  2018
# 9169     True       True          True                True  2018
# 9181     True       True          True                True  2018
# 9193     True       True          True                True  2018
# 9196     True       True          True                True  2020
#
# [252 rows x 19 columns]

# %% [markdown]
# ### Simple mapping for drivetrain, fuel type

# %%
df_expand.drive_train.unique()
# Out:
# array(['Front-wheel Drive', 'All-wheel Drive', 'Four-wheel Drive', 'AWD',
#        'Rear-wheel Drive', '4WD', 'FWD', 'RWD', '–', 'Four Wheel Drive'],
#       dtype=object)

# %%
drive_train_list = ['FWD', 'AWD', 'AWD', 'AWD', 'RWD', 'AWD', 'FWD', 'RWD', 'unknown', 'AWD']
df_expand['drive_train_simple'] = df_expand['drive_train'].map(dict(zip(df_expand.drive_train.unique(), drive_train_list)))

# %%
df_expand.fuel_type.unique()
# Out:
# array(['Gasoline', 'Hybrid', 'Electric', 'E85 Flex Fuel', 'Diesel', '–',
#        'Flexible Fuel', 'Gasoline/Mild Electric Hybrid', 'Gasoline Fuel'],
#       dtype=object)

# %%
fuel_type_list = ['Gasoline', 'Hybrid', 'Electric', 'Flexible Fuel', 'Diesel', '', 'Flexible Fuel', 'Hybrid', 'Gasoline']
df_expand['fuel_type_simple'] = df_expand['fuel_type'].map(dict(zip(df_expand.fuel_type.unique(), fuel_type_list)))

# %% [markdown]
# ### Extracting emission, cylinder, turbo, average mpg, transmission

# %%
df_expand['turbo'] = df_expand['engine'].apply(lambda x: 'turbo' in x.lower())

# %%
def extract_emission_cylinder(engine):
    if engine == 'Electric':
        return (0.0, 'E')
    else:
        if re.search(r'\d.(\d *L|\d$)', engine):
            em = float(re.search(r'\d.(\d *L|\d$)', engine).group(0).replace('L', '').strip())
        else:
            em = -1.0
        if re.search(r'[V|I|H]-*\d{1,2}', engine):
            cy = re.search('[V|I|H]-*\d{1,2}', engine).group(0).replace('-', '')
        else:
            cy = ''
    return (em, cy)

# %%
df_expand['emission'] = df_expand.apply(lambda x: extract_emission_cylinder(x['engine'])[0], axis=1)
df_expand['cylinder'] = df_expand.apply(lambda x: extract_emission_cylinder(x['engine'])[1], axis=1)

# %%
def get_average_mpg(range_mpg, fuel_type):
    if fuel_type == 'Electric':
        return 0.0
    elif range_mpg == 'Transmission':
        return -1.0
    else:
        if '–' in range_mpg:
            mpg_min = int(range_mpg[:range_mpg.index('–')])
            mpg_max = int(range_mpg[range_mpg.index('–') + 1:])
            if mpg_min > mpg_max:
                mpg_min = mpg_max
            return (mpg_min + mpg_max) / 2
        else:
            return float(range_mpg)

# %%
df_expand['average_mpg'] = df_expand.apply(lambda x: get_average_mpg(x['mpg'], x['fuel_type_simple']), axis=1)

# %%
def extract_transmission(transmission, fuel_type):
    if fuel_type == 'Electric':
        return 0
    else:
        if re.search(r'\d{1,2}-* *(speed|spd)', transmission.lower()):
            return int(re.search(r'\d{1,2}-* *(speed|spd)', transmission.lower()).group(0)
                       .replace('speed', '').replace('spd', '').replace('-', '').strip())
        else:
            return -1

# %%
df_expand['transmission_simple'] = df_expand.apply(lambda x:extract_transmission(x['transmission'], x['fuel_type_simple']), axis=1)

# %%
performance_list = ['drive_train_simple', 'fuel_type_simple', 'average_mpg', 'emission', 'cylinder', 'transmission_simple']

# %%
df_expand.head()
# Out:
#                                      name  price        exterior_color  \
# 0               2018 Ford Escape Titanium  25411         Blue Metallic
# 1              2013 Jaguar XJ L Portfolio  28977        Ultimate Black
# 2              2020 Volvo S60 T5 Momentum  32900  Osmium Gray Metallic
# 3  2021 Toyota Highlander Hybrid Platinum  49846                 Black
# 4               2020 Lexus NX 300 F Sport  38689         Atomic Silver
#
#    interior_color        drive_train    mpg fuel_type       transmission  \
# 0  Charcoal Black  Front-wheel Drive  21–28  Gasoline  6-Speed Automatic
# 1             Jet    All-wheel Drive  16–24  Gasoline  8-Speed Automatic
# 2        Charcoal  Front-wheel Drive  23–34  Gasoline  8-Speed Automatic
# 3               –    All-wheel Drive  35–34    Hybrid      Automatic CVT
# 4             Red  Front-wheel Drive  22–28  Gasoline  6-Speed Automatic
#
#                               engine  mileage  ...  brake_assist  \
# 0         2.0L I4 16V GDI DOHC Turbo    47114  ...          True
# 1  3.0L V6 24V GDI DOHC Supercharged    31208  ...          True
# 2         2.0L I4 16V GDI DOHC Turbo    20077  ...          True
# 3        2.5L I4 16V PDI DOHC Hybrid    35335  ...          True
# 4         2.0L I4 16V PDI DOHC Turbo    26583  ...          True
#
#    blind_spot_monitor  year  drive_train_simple  fuel_type_simple  turbo  \
# 0                True  2018                 FWD          Gasoline   True
# 1               False  2013                 AWD          Gasoline  False
# 2               False  2020                 FWD          Gasoline   True
# 3               False  2021                 AWD            Hybrid  False
# 4               False  2020                 FWD          Gasoline   True
#
#    emission  cylinder  average_mpg transmission_simple
# 0       2.0        I4         24.5                   6
# 1       3.0        V6         20.0                   8
# 2       2.0        I4         28.5                   8
# 3       2.5        I4         34.0                  -1
# 4       2.0        I4         25.0                   6
#
# [5 rows x 26 columns]

# %% [markdown]
# ## Simple plots

# %%
# alt.Chart(df_expand).mark_bar(color='green').transform_filter(
#     alt.datum['price'] <= 120000
# ).encode(
#     x=alt.X('price:Q', bin=alt.Bin(maxbins=20)),
#     y=alt.Y('count():Q')
# )

# %%
def price_level(price):
    if price > 60000:
        return 'expensive'
    elif price <=60000 and price > 20000:
        return 'moderate'
    else:
        return 'cheap'

# %%
df_expand['price_level'] = df_expand['price'].apply(price_level)

# %%
# alt.Chart(df_expand).transform_filter(
#     (alt.datum['price'] <= 120000 & alt.datum['drive_train_simple'] != 'none' & alt.datum['year'] > 2005)
# ).mark_bar().encode(
#     x=alt.X('year:N'),
#     y=alt.Y('count():Q'),
#     color=alt.Color('drive_train_simple:N')
# )

# %%
len(df_expand[df_expand.fuel_type_simple == 'Electric']) /9204
# Out:
# 0.015428074750108649

# %%
df_expand.price.mean()
# Out:
# 39279.23468057367

# %%
df_expand.reset_index(inplace=True)
df_expand = df_expand.rename(columns = {'index':'id', 'name':'contents'})
df_expand.head()
# Out:
#    id                                contents  price        exterior_color  \
# 0   0               2018 Ford Escape Titanium  25411         Blue Metallic
# 1   1              2013 Jaguar XJ L Portfolio  28977        Ultimate Black
# 2   2              2020 Volvo S60 T5 Momentum  32900  Osmium Gray Metallic
# 3   3  2021 Toyota Highlander Hybrid Platinum  49846                 Black
# 4   4               2020 Lexus NX 300 F Sport  38689         Atomic Silver
#
#    interior_color        drive_train    mpg fuel_type       transmission  \
# 0  Charcoal Black  Front-wheel Drive  21–28  Gasoline  6-Speed Automatic
# 1             Jet    All-wheel Drive  16–24  Gasoline  8-Speed Automatic
# 2        Charcoal  Front-wheel Drive  23–34  Gasoline  8-Speed Automatic
# 3               –    All-wheel Drive  35–34    Hybrid      Automatic CVT
# 4             Red  Front-wheel Drive  22–28  Gasoline  6-Speed Automatic
#
#                               engine  ...  blind_spot_monitor  year  \
# 0         2.0L I4 16V GDI DOHC Turbo  ...                True  2018
# 1  3.0L V6 24V GDI DOHC Supercharged  ...               False  2013
# 2         2.0L I4 16V GDI DOHC Turbo  ...               False  2020
# 3        2.5L I4 16V PDI DOHC Hybrid  ...               False  2021
# 4         2.0L I4 16V PDI DOHC Turbo  ...               False  2020
#
#    drive_train_simple  fuel_type_simple  turbo  emission  cylinder  \
# 0                 FWD          Gasoline   True       2.0        I4
# 1                 AWD          Gasoline  False       3.0        V6
# 2                 FWD          Gasoline   True       2.0        I4
# 3                 AWD            Hybrid  False       2.5        I4
# 4                 FWD          Gasoline   True       2.0        I4
#
#    average_mpg  transmission_simple  price_level
# 0         24.5                    6     moderate
# 1         20.0                    8     moderate
# 2         28.5                    8     moderate
# 3         34.0                   -1     moderate
# 4         25.0                    6     moderate
#
# [5 rows x 28 columns]

# %%
df_expand.to_json("data.json", orient='records', lines=True)

# %% [markdown]
# ## Produce single string form for baseline

# %%
df_expand_long = pd.concat([df.drop(['basics', 'features'], axis=1), 
                       df['basics'].apply(pd.Series), df['features'].apply(pd.Series)], axis=1)

# %%
config_list = safety_list + comfort_list + multimedia_list

# %%
for conf in config_list:
    df_expand_long[conf] = df_expand_long[conf].apply(lambda x: conf if x else 'no ' + conf)

# %%
df_expand_long['price'] = df_expand_long['price'].apply(str)
df_expand_long['mileage'] = df_expand_long['mileage'].apply(str)
df_expand_long['content'] = df_expand_long.apply(', '.join, axis=1)

# %%
df_expand_long[['content']].to_csv('joined.csv', index_label='docid')
